# %% [markdown]
# <a href="https://colab.research.google.com/github/felippedamasopy/PY---Imports-Others-Data-Fonts/blob/main/Other_data_formats_for_use_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_jason  = pd.read_json('aluguel.json')
df_jason.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# 4    800       230.0     NaN

# %%
df_txt  = pd.read_table('aluguel.txt')
df_txt.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# 4    800       230.0     NaN

# %%
df_xlsx  = pd.read_excel('aluguel.xlsx')
df_xlsx.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# 4    800       230.0     NaN

# %%
df_html = pd.read_html('dados_html_1.html')
df_html
# Out:
# [  FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
#  0      00 A 18               R$218,99           R$192,60    R$334,48
#  1      19 A 23               R$263,63           R$207,67    R$380,06
#  2      24 A 28               R$322,44           R$224,26    R$464,39
#  3      29 A 33               R$402,05           R$258,63    R$566,68
#  4      34 A 38               R$455,17           R$306,37    R$664,61
#  5      39 A 43               R$489,29           R$417,93    R$742,72
#  6      44 A 48               R$582,65           R$495,24    R$869,47
#  7      49 A 53               R$718,86           R$562,64  R$1.046,29
#  8      54 A 58               R$908,54           R$721,00  R$1.355,74
#  9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53]

# %%
df_html1 = pd.read_html('dados_html_2.html')
df_html1
# Out:
# [                  Date      Reserve balances required  \
#                    Date Reserve balance requirements 1
#  0              Month 7                        Month 7
#  1            Apr. 2017                         113224
#  2             May 2017                         115464
#  3            June 2017                         118187
#  4            July 2017                         120636
#  5            Aug. 2017                         120091
#  6           Sept. 2017                         122109
#  7            Oct. 2017                         116873
#  8            Nov. 2017                         123141
#  9            Dec. 2017                         123720
#  10           Jan. 2018                         126792
#  11           Feb. 2018                         124006
#  12           Mar. 2018                         120285
#  13           Apr. 2018                         126415
#  14                 NaN                            NaN
# ...
